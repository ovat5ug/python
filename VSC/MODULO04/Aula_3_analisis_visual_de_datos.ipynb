# %% [markdown]
# # Analisis de variables categóricas

# %%
import pandas as pd
#pip install Seaborn biblioteca para analisis estadisticos por medio de grafiscos de diseños
#variados y coloridos
import seaborn as sns
tarjetas=pd.read_csv('credit_card_ESP_rangoEdad.csv')
tarjetas['iu'] = tarjetas['valor_factura'] / tarjetas['limite']
#"iu" = indice de uso: es el porcentae que se le da a una persona por el uso de la tarjeta
#en por centaje por cien

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad
# 0    6022               Si     2.Universidad     Casado/a    24  \
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.countplot(x='cuenta_corriente', data= tarjetas)
#nuestra variables categoricas "cuenta_corriente"
# Out:
# <Axes: xlabel='cuenta_corriente', ylabel='count'>

# %%
sns.countplot(x='cuenta_corriente', data= tarjetas, hue='moroso', palette='coolwarm')
#nuestra variables categoricas "cuenta_corriente" y "moroso"
# Out:
# <Axes: xlabel='cuenta_corriente', ylabel='count'>

# %%
sns.catplot(x='estado_civil', y='limite', data=tarjetas, hue='moroso', dodge=True)

# %%
sns.swarmplot(x='escolaridad', y='iu', data=tarjetas, palette="deep")
# Out:
# C:\Users\yahoo\AppData\Local\Temp\ipykernel_16836\1144083228.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='escolaridad', y='iu', data=tarjetas, palette="deep")
# C:\Users\yahoo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\yahoo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\categorical.py:3544: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='escolaridad', ylabel='iu'>
# ...

# %%
sns.boxplot(x='escolaridad', y='iu', data=tarjetas, hue='moroso', palette='bone')
#linea inferior significa limite minimo
#linea superior significa limite maximo
#la linea de en medio significa la mediaana
#si la mediana esta por debajo es que es menor al 50% y el limete inferior de esta es el 25%
#si la mediana esta por encima es que es mayor al 50% y el limete superior de esta es el 75%
# Out:
# <Axes: xlabel='escolaridad', ylabel='iu'>

# %%
sns.violinplot(x='escolaridad', y='iu', data=tarjetas, hue='moroso')
# Out:
# <Axes: xlabel='escolaridad', ylabel='iu'>

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad
# 0    6022               Si     2.Universidad     Casado/a    24  \
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
tarjetas.edad.unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72],
#       dtype=int64)

# %%
bins = [20, 30, 40, 50, 100]
nombres = ['20-30', '30-40', '40-50', '50+']

tarjetas['rango_edad'] = pd.cut(tarjetas['edad'], bins, labels=nombres)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad
# 0    6022               Si     2.Universidad     Casado/a    24  \
# 1   36132               Si     2.Universidad    Soltero/a    26
# 2   27099               Si     2.Universidad    Soltero/a    34
# 3   15055               Si     2.Universidad     Casado/a    37
# 4  150550               No  3.Pos-graduación    Soltero/a    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.boxplot(x='rango_edad', y='limite', data= tarjetas);

# %%
tarjetas.to_csv('credit_card_ESP_rangoEdad.csv', sep = ',', index = False)
#importando los cambios efectuados a la traduccion de la tabla
tarjetas
# Out:
#       limite cuenta_corriente       escolaridad estado_civil  edad
# 0       6022               Si     2.Universidad     Casado/a    24  \
# 1      36132               Si     2.Universidad    Soltero/a    26
# 2      27099               Si     2.Universidad    Soltero/a    34
# 3      15055               Si     2.Universidad     Casado/a    37
# 4     150550               No  3.Pos-graduación    Soltero/a    29
# ...      ...              ...               ...          ...   ...
# 1495   54198               Si  3.Pos-graduación    Soltero/a    27
# 1496   45165               No     2.Universidad     Casado/a    55
# 1497   78286               No  3.Pos-graduación    Soltero/a    34
# 1498    6022               No     2.Universidad     Casado/a    44
# 1499  183671               No  3.Pos-graduación    Soltero/a    31
#
#       valor_factura  valor_pago  moroso        iu rango_edad
# 0          934.0122      0.0000       1  0.155100      20-30
# ...
